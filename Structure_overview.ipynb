# %%
from lolviz import *
from TreeNode import TreeNode
from TreeNode import Tree
import random
import queue
from LinkedList import LinkedNode
from LinkedList import LinkedList
import time
import matplotlib.pyplot as plt
from IPython.display import HTML, display
import tabulate

# %% [markdown]
# # Normal List

# %%
#normal list
list1 = ['a', 'b', 'c', 'd', 'e']
listviz(list1)

# %% [markdown]
# # Stack Structure

# %%
#use list as a stack
stack = [3, 4, 5]
listviz(stack)

# %%
#push item into the end of the list
stack.append(6)
stack.append(7)
listviz(stack)

# %%
#pop item out of the list
stack.pop()
listviz(stack)

# %% [markdown]
# # Double List(Table/Matrix)

# %%
#table/matrix structure 
table=[
    ['Year', 'Name', 'Grade', 'Class Number', 'Score'],
    [2019,'Jack','First year',3,82],
    [2019,'Lily','First year',3,76],
    [2019,'John','First year',3,90],
    [2019,'Will','First year',3,56],
    [2019,'Shawn','First year',3,78],
]
objviz(table)

# %% [markdown]
# # Set Structure

# %%
#set structrue
basket = {"apple", "banana", "pear", "apple"}
objviz(basket) #set will remove the duplicated item

# %% [markdown]
# # Queue Structure

# %%
q = queue.Queue()
for i in range(5):
    q.put(i)
objviz(q)

# %% [markdown]
# # Tree Structure

# %%
tree = Tree()
tree.insert(2)
for count in range(10):
     tree.insert(random.randint(1, 10))
objviz(tree)

# %% [markdown]
# # Dictionary Structure

# %%
dict = {'a': 1, 'b': 2, 'c': '3'}
objviz(dict)

# %% [markdown]
# # Insert Problem
# In this part, we will test insert data into different data structures to test the average time for each and then print out a graph to demonstrate and compare the results between each other.

# %% [markdown]
# ### Format data

# %%
data = [random.randint(0, 10000) for r in range(10000)]
time_insert = []
name = []
table_plot = [[]]

# %% [markdown]
# ### Insert data into list structure

# %% [markdown]
# ##### Due to the similar structure of stack and list, the data insert time should share the similar time.

# %%
count_time = 0
data_list = []
for count in range(100):
    start_time = time.time()
    for num in data:
        data_list.append(num)
    count_time += time.time() - start_time

list_insert_time = round(count_time / 100, 5)
print(list_insert_time)
time_insert.append(list_insert_time)
name.append('List')
# Out:
# 0.00123

# %% [markdown]
# ### Insert data into tree structure

# %%
count_time = 0
data_tree = Tree()
for count in range(100):
    start_time = time.time()
    for num in data:
        data_tree.insert(num)
    count_time += time.time() - start_time
    
tree_insert_time = round(count_time / 100, 5)
print(tree_insert_time)
time_insert.append(tree_insert_time)
name.append('Tree')
# Out:
# 0.04031

# %% [markdown]
# ### Insert data into set structure

# %%
count_time = 0
data_set = set()
for count in range(100):
    start_time = time.time()
    for num in data:
        data_set.add(num)
    count_time += time.time() - start_time

set_insert_time = round(count_time / 100, 5)
print(set_insert_time)
time_insert.append(set_insert_time)
name.append('Set')
# Out:
# 0.00109

# %% [markdown]
# ### Insert data into dictionary structure

# %%
count_time = 0
data_dict = {}
for count in range(100):
    start_time = time.time()
    for num in data:
        data_dict[num] = num
    count_time += time.time() - start_time

dict_insert_time = round(count_time / 100, 5)
print(dict_insert_time)
time_insert.append(dict_insert_time)
name.append('Dictionary')
# Out:
# 0.00102

# %% [markdown]
# ### Insert data into single linked list data structure

# %%
count_time = 0
data_linked_list = LinkedList()
for count in range(100):
    start_time = time.time()
    for num in data:
        data_linked_list.addNode(num)
    count_time += time.time() - start_time

linked_list_insert_time = round(count_time / 100, 5)
print(linked_list_insert_time)
time_insert.append(linked_list_insert_time)
name.append('Linked List')
# Out:
# 0.01616

# %% [markdown]
# ### Plot the Diagram

# %%
fig, ax = plt.subplots()
print(time_insert)
index = range(len(name))

print(index)
ax.bar(index, time_insert)
ax.set_xticks(range(len(name)))
ax.set_xticklabels(name)
ax.set_xlabel('Data Structure Name', weight='semibold')
ax.set_ylabel('Time', weight='semibold')
ax.set_title("Insert Time of Different Data Structure", fontsize=15)
for a,b in zip(index, time_insert):
    plt.text(a - 0.3, b+0.0003, str(b))
plt.show()

    
table_plot = [['Name', 'Insert Time']]
for i in range(len(name)):
    table_plot.append([name[i], time_plot[i]])
display(HTML(tabulate.tabulate(table_plot, tablefmt='html')))
# Out:
# [0.00123, 0.04031, 0.00109, 0.00102, 0.01616]
# range(0, 5)
# <table>
# <tbody>
# <tr><td>Name       </td><td>Insert Time</td></tr>
# <tr><td>List       </td><td>0.00109    </td></tr>
# <tr><td>Tree       </td><td>0.03653    </td></tr>
# <tr><td>Set        </td><td>0.00111    </td></tr>
# <tr><td>Dictionary </td><td>0.00108    </td></tr>
# <tr><td>Linked List</td><td>0.01598    </td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## Search Problem
# We will use a huge dataset to test different data structures

# %% [markdown]
# ### Define data holder and a random index list between 0 and 9999 for searching targets

# %%
time_search = []
targets = [ random.randint(0,9999) for i in range(50)]
print(targets)
# Out:
# [7266, 8362, 2641, 9990, 585, 4053, 7080, 2314, 7278, 8774, 9250, 9852, 6298, 453, 1072, 4553, 103, 2989, 2313, 8317, 7069, 187, 5210, 920, 9765, 5383, 5806, 8577, 4517, 1466, 9816, 1539, 3281, 4296, 5247, 4964, 61, 4363, 4366, 7221, 4074, 1908, 2801, 7052, 3172, 5407, 9259, 1713, 4231, 2291]

# %% [markdown]
# ### List Searching can only rely on iterating the whole list to compare each item

# %%
count_time = 0
for target in targets:
    start_time = time.time()
    for i in range(len(data_list)):
        if data_list[i] == data[target]:
            count_time += time.time() - start_time
            break
time_search.append(count_time / 50 )
print(count_time)
# Out:
# 0.0240631103515625

# %% [markdown]
# ### Tree Searching

# %%
count_time = 0
for target in targets:
    start_time = time.time()
    data_tree.search(data[target])
    count_time += time.time() - start_time
time_search.append(count_time / 50 )
print(count_time)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-4ab5cb414236> in <module>
#       2 for target in targets:
#       3     start_time = time.time()
# ----> 4     data_tree.search(data[target])
#       5     count_time += time.time() - start_time
#       6 time_search.append(count_time / 50 )
#
# C:\Projects\python_structure\TreeNode.py in search(self, value)
#     110     def search(self, value):
#     111         if self.root:
# --> 112             return self.root.search(value)
#     113         else:
#     114             return self
#
# C:\Projects\python_structure\TreeNode.py in search(self, value)
#      39             return self.right.search(value)
#      40         elif self.value > value:
# ---> 41             return self.left.search(value)
#      42
#      43     #define printing Tree in inorder
#
# C:\Projects\python_structure\TreeNode.py in search(self, value)
#      39             return self.right.search(value)
#      40         elif self.value > value:
# ---> 41             return self.left.search(value)
#      42
#      43     #define printing Tree in inorder
#
# C:\Projects\python_structure\TreeNode.py in search(self, value)
#      37             return root
#      38         elif self.value < value:
# ---> 39             return self.right.search(value)
#      40         elif self.value > value:
#      41             return self.left.search(value)
#
# C:\Projects\python_structure\TreeNode.py in search(self, value)
#      37             return root
#      38         elif self.value < value:
# ---> 39             return self.right.search(value)
#      40         elif self.value > value:
#      41             return self.left.search(value)
#
# C:\Projects\python_structure\TreeNode.py in search(self, value)
#      37             return root
#      38         elif self.value < value:
# ---> 39             return self.right.search(value)
#      40         elif self.value > value:
#      41             return self.left.search(value)
#
# C:\Projects\python_structure\TreeNode.py in search(self, value)
#      39             return self.right.search(value)
#      40         elif self.value > value:
# ---> 41             return self.left.search(value)
#      42
#      43     #define printing Tree in inorder
#
# C:\Projects\python_structure\TreeNode.py in search(self, value)
#      39             return self.right.search(value)
#      40         elif self.value > value:
# ---> 41             return self.left.search(value)
#      42
#      43     #define printing Tree in inorder
#
# C:\Projects\python_structure\TreeNode.py in search(self, value)
#      37             return root
#      38         elif self.value < value:
# ---> 39             return self.right.search(value)
#      40         elif self.value > value:
#      41             return self.left.search(value)
#
# C:\Projects\python_structure\TreeNode.py in search(self, value)
#      37             return root
#      38         elif self.value < value:
# ---> 39             return self.right.search(value)
#      40         elif self.value > value:
#      41             return self.left.search(value)
#
# C:\Projects\python_structure\TreeNode.py in search(self, value)
#      35     def search(self, value):
#      36         if self is None or self.value == value:
# ---> 37             return root
#      38         elif self.value < value:
#      39             return self.right.search(value)
#
# NameError: name 'root' is not defined
