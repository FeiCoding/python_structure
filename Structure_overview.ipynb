# %%
from lolviz import *
from TreeNode import Node
from TreeNode import Tree
import random

# %% [markdown]
# # Normal List

# %%
#normal list
list1 = ['a', 'b', 'c', 'd', 'e']
listviz(list1)

# %% [markdown]
# # Stack Structure

# %%
#use list as a stack
stack = [3, 4, 5]
listviz(stack)

# %%
#push item into the end of the list
stack.append(6)
stack.append(7)
listviz(stack)

# %%
#pop item out of the list
stack.pop()
listviz(stack)

# %% [markdown]
# # Double List(Table/Matrix)

# %%
#table/matrix structure 
table=[
    ['Year', 'Name', 'Grade', 'Class Number', 'Score'],
    [2019,'Jack','First year',3,82],
    [2019,'Lily','First year',3,76],
    [2019,'John','First year',3,90],
    [2019,'Will','First year',3,56],
    [2019,'Shawn','First year',3,78],
]
objviz(table)

# %%
#set structrue
basket = {"apple", "banana", "pear", "apple"}
objviz(basket) #set will remove the duplicated item

# %% [markdown]
# # Tree Structure

# %%
root = Tree()
root.insert(2)
for count in range(10):
     root.insert(random.randint(1, 10))
objviz(root)

# %% [markdown]
# # Search Problem
# Insert data to pre-difined data strucutre

# %% [markdown]
# ## Search Problem
# We will use a huge dataset to test different data structures

# %%
import time
start = time.time()





end = time.time()
print(end - start)
# Out:
# 0.0
